# %%
# %pip install ipympl
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
# Include this line to make plots interactive
# %matplotlib widget
# Out:
# Requirement already satisfied: ipympl in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipympl) (8.15.0)
# Requirement already satisfied: numpy in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipympl) (1.24.3)
# Requirement already satisfied: ipython-genutils in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: traitlets<6 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipympl) (5.7.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipympl) (8.0.4)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipympl) (3.7.2)
# Requirement already satisfied: backcall in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (2.15.1)
# Requirement already satisfied: stack-data in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: exceptiongroup in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (1.0.4)
# Requirement already satisfied: pexpect>4.3 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: appnope in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.3.0)
# Requirement already satisfied: nest-asyncio in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: psutil in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: asttokens in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: entrypoints in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/juanlavierigoiri/anaconda3/envs/dev/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (3.10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set x axis to numerical value for month
x_axis = np.arange(1, 13, 1)

# %%
# Avearge weather temp
points_F = [39, 42, 51, 62, 72, 82, 86, 84, 77, 65, 55, 44]

# %%
# Convert to Celsius C = (F-32) * 0.56
points_C = [(x-32) * 0.56 for x in points_F]
points_C
# Out:
# [3.9200000000000004,
#  5.6000000000000005,
#  10.64,
#  16.8,
#  22.400000000000002,
#  28.000000000000004,
#  30.240000000000002,
#  29.120000000000005,
#  25.200000000000003,
#  18.48,
#  12.88,
#  6.720000000000001]

# %%
# Create a handle for each plot
fahrenheit, = plt.plot(x_axis, points_F, marker="+",color="blue", linewidth=1, label="Fahrenheit")
celcius, = plt.plot(x_axis, points_C, marker="s", color="Red", linewidth=1, label="Celcius")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Set our legend to where the chart thinks is best
plt.legend(handles=[fahrenheit, celcius], loc="best")

# %%
# Create labels for the X and Y axis
plt.xlabel("Months")
plt.ylabel("Degrees")
# Out:
# Text(46.972222222222214, 0.5, 'Degrees')

# %%
# Save and display the chart
plt.savefig("../Images/avg_temp.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
