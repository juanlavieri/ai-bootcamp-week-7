# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib widget

# %%
cities = ["San Francisco", "Omaha", "New Orleans", "Cincinnati", "Pittsburgh"]
cars_in_cities = [214.7, 564.4, 416.5, 466.7, 350.6]
x_axis = np.arange(len(cars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, cars_in_cities, color="b", align="center")
# Out:
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x7f8b15d42260>,
#   <matplotlib.axis.XTick at 0x7f8b15d42230>,
#   <matplotlib.axis.XTick at 0x7f8b15dbe9b0>,
#   <matplotlib.axis.XTick at 0x7f8b15dbf220>,
#   <matplotlib.axis.XTick at 0x7f8b15dbfcd0>],
#  [Text(0, 0, 'San Francisco'),
#   Text(1, 0, 'Omaha'),
#   Text(2, 0, 'New Orleans'),
#   Text(3, 0, 'Cincinnati'),
#   Text(4, 0, 'Pittsburgh')])

# %%
# Set the limits of the x axis
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(cars_in_cities)+50)
# Out:
# (0.0, 614.4)

# %%
# Give the chart a title, x label, and y label
plt.title("Cars in Cities")
plt.xlabel("Cities")
plt.ylabel("Cars (in Millions)")
# Out:
# Text(109.90000740687053, 0.5, 'Cars (in Millions)')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("../Images/CarsInCities.png")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
